# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 dataset = pd.read_csv("diabetes.csv")

# %%
dataset.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.select_dtypes(include="number").columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
for i in dataset.select_dtypes(include="number").columns:
    sns.boxplot(dataset[i])
    plt.show()

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# Importing SequentialFeatureSelector from mlxtend's feature_selection module

# %%
try:
    import mlxtend
    print("mlxtend is installed!")
    print("Version:", mlxtend.__version__)
except ModuleNotFoundError:
    print("mlxtend is not installed.")
# Out:
# mlxtend is installed!
# Version: 0.23.3

# %%
x = dataset.iloc[:,:-1]
y = dataset["Outcome"]

# %%
x.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32

# %%
y.head(3)
# Out:
# 0    1
# 1    0
# 2    1
# Name: Outcome, dtype: int64

# %%
x.shape
# Out:
# (768, 8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %% [markdown]
# Forward Elimination(using MLXTEND) Feature Selection)

# %%
fs=SequentialFeatureSelector(lr,k_features=5,forward=True)
fs.fit(x,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(5, 5),
#                           scoring='accuracy')

# %%
fs.feature_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
fs.k_feature_names_
# Out:
# ('Pregnancies', 'Glucose', 'Insulin', 'BMI', 'Age')

# %%
fs.k_score_
# Out:
# 0.7708768355827178

# %% [markdown]
# Backward Elimination(using MLXTEND) Feature Selection)

# %%
s=SequentialFeatureSelector(lr,k_features=5,forward=False)
fs.fit(x,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(5, 5),
#                           scoring='accuracy')

# %%
fs.feature_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
fs.k_feature_names_
# Out:
# ('Pregnancies', 'Glucose', 'Insulin', 'BMI', 'Age')

# %%
fs.k_score_
# Out:
# 0.7708768355827178
